# %%
import os
dir = 'aot_cleaned/s1'
for filename in os.listdir(dir):
    with open(f'{dir}/{filename}') as input:
        with open(f'{dir}/s1',"a") as output:
            for line in input:
                output.write(line)
                #output.write(line.replace('\\N',' '))

# %%
import nltk
from collections import Counter
from nltk.stem import WordNetLemmatizer 
nltk.download('punkt')
nltk.download('wordnet')

# %%
dir = 'aot_cleaned/s1'

# %%
file_content = open(f'{dir}/s1').read()
tokens = nltk.word_tokenize(file_content)

# %%
repeated_words = ['know','back','want','going','could','would','even','hey','\'ve','get','ca','like','let','one','think','go','right','\'m','us','...','that','.',',','?','i','n\'t','\'s','\'re','\'ll','(',')', 'me','that','you', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't",'!', 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
lowered_tokens = [token.lower() for token in tokens]
new_tokens = [token for token in lowered_tokens if token not in repeated_words]

# %%
lemmatizer = WordNetLemmatizer()
lem_tokens = [lemmatizer.lemmatize(token) for token in new_tokens]

# %%
from wordcloud import WordCloud

wc = WordCloud()
str = ' '.join(lem_tokens)
img = wc.generate_from_text(str)
img.to_file('worcloud.jpeg') # example of something you can do with the img

# %%
counter = Counter(lem_tokens)
most_occur = Counter.most_common(counter)
print(most_occur)
# Out:
# [('titan', 529), ('eren', 406), ('wall', 239), ('humanity', 134), ('time', 128), ('corp', 124), ('survey', 113), ('mikasa', 111), ('see', 108), ('armin', 105), ('kill', 96), ('way', 94), ('fight', 91), ('yes', 87), ('{', 86), ('}', 86), ('die', 83), ("'d", 79), ('wo', 78), ('life', 76), (':', 76), ('wait', 75), ('really', 74), ('still', 74), ('far', 73), ('captain', 72), ('look', 71), ('military', 71), ('human', 70), ('year', 68), ('take', 67), ('sir', 67), ('soldier', 66), ('never', 65), ('must', 65), ('annie', 64), ('well', 62), ('commander', 61), ('make', 60), ('say', 60), ('damn', 59), ('squad', 59), ('information', 58), ('stop', 57), ('need', 56), ('police', 56), ('something', 56), ('come', 55), ('yeah', 55), ('female', 54), ('mean', 53), ('everyone', 53), ('world', 52), ('many', 51), ('day', 51), ('share', 51), ('believe', 51), ('gate', 50), ('thing', 50), ("''", 50), ('plan', 49), ('enough', 49), ('maneuver', 49), ('two', 49), ('people', 49), ('sorry', 48), ('levi', 48), ('any
# ...
